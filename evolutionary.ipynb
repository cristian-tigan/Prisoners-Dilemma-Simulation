# %% [markdown]
# * Iterate what done in the previous task (repeated MPIPD, rMPIPD)  by increasing the population implementing a given strategy depending on the results that strategy achieved in the previous iteration

# %%
import pandas as pd
from core.match import Match
from core.payoff import PayoffMatrix
from strategies.basic import AlwaysCooperate, AlwaysDefect
from strategies.advanced import TitForTat, Random

# %%
# Matches Parameters
M = PayoffMatrix()
N_rounds = 50

# Initial players population
players = [AlwaysCooperate(), AlwaysDefect(), TitForTat(),
           Random(name='Mainly Nice', p=0.7), Random(name='Mainly Bad', p=0.3)]
N = len(players)

for l in range(10):
    print(f"--- GENERATION {l+1} ---")
    
    # Reset lists for each generation (since population changes)
    matches = []
    results = []
    dfs = []
    
    # Use lists for dynamic sizing (easier to extend than NumPy arrays)
    N_wins = [0] * N
    N_ties = [0] * N
    Total_score = [0] * N
    Total_score_list = []
    
    # Create matches for the current population
    for i in range(N):
        for j in range(i+1, N):
            m = Match(players[i], players[j], M)
            matches.append((i, j, m))
    
    # Run all matches
    for i, j, match in matches:
        result = match.run(rounds=N_rounds)
        results.append(result)
        
        name1 = result['agent_a']
        name2 = result['agent_b']
        score1 = result['score_a']
        score2 = result['score_b']
        
        # Update wins/ties
        if score1 > score2:
            N_wins[i] += 1
        elif score1 < score2:
            N_wins[j] += 1
        else:
            N_ties[i] += 1
            N_ties[j] += 1
        
        # Update total scores
        Total_score[i] += score1
        Total_score[j] += score2
    
    # Build score list for finding the best
    for i in range(N):
        Total_score_list.append((players[i].name, Total_score[i]))
    
    # Find the best strategy index
    best_index = Total_score.index(max(Total_score))  # Using list.index for simplicity
    
    # Append the best strategy instance to players
    players.append(players[best_index])
    N = len(players)  # Update N for the next generation
    
    print(f"Best Strategy of Generation {l+1}: {players[best_index].name} with score {Total_score[best_index]}")
    for i in range(len(Total_score)):  # Print only for the current generation's players
        print(f"{players[i].name} - Wins: {N_wins[i]}, Ties: {N_ties[i]}, Total Score: {Total_score[i]}")
    print(f"Updated Population Size: {N}")
    print("")
# Out:
# --- GENERATION 1 ---
# Best Strategy of Generation 1: AlwaysDefect with score 596
# AlwaysCooperate - Wins: 0, Ties: 1, Total Score: 315
# AlwaysDefect - Wins: 4, Ties: 0, Total Score: 596
# TitForTat - Wins: 0, Ties: 2, Total Score: 414
# Mainly Nice - Wins: 1, Ties: 1, Total Score: 396
# Mainly Bad - Wins: 3, Ties: 0, Total Score: 491
# Updated Population Size: 6
#
# --- GENERATION 2 ---
# Best Strategy of Generation 2: AlwaysDefect with score 650
# AlwaysCooperate - Wins: 0, Ties: 1, Total Score: 312
# AlwaysDefect - Wins: 4, Ties: 1, Total Score: 634
# TitForTat - Wins: 0, Ties: 1, Total Score: 475
# Mainly Nice - Wins: 2, Ties: 0, Total Score: 417
# Mainly Bad - Wins: 3, Ties: 0, Total Score: 534
# AlwaysDefect - Wins: 4, Ties: 1, Total Score: 650
# Updated Population Size: 7
#
# --- GENERATION 3 ---
# Best Strategy of Generation 3: AlwaysDefect with score 712
# AlwaysCooperate - Wins: 0, Ties: 1, Total Score: 291
# AlwaysDefect - Wins: 4, Ties: 2, Total Score: 696
# TitForTat - Wins: 0, Ties: 2, Total Score: 511
# Mainly Nice - Wins: 1, Ties: 1, Total Score: 417
# Mainly Bad - Wins: 3, Ties: 0, Total Score: 587
# AlwaysDefect - Wins: 4, Ties: 2, Total Score: 712
# AlwaysDefect - Wins: 4, Ties: 2, Total Score: 712
# Updated Population Size: 8
#
# --- GENERATION 4 ---
# Best Strategy of Generation 4: AlwaysDefect with score 778
# AlwaysCooperate - Wins: 0, Ties: 1, Total Score: 267
# AlwaysDefect - Wins: 4, Ties: 3, Total Score: 762
# TitForTat - Wins: 0, Ties: 2, Total Score: 565
# Mainly Nice - Wins: 2, Ties: 0, Total Score: 449
# Mainly Bad - Wins: 2, Ties: 1, Total Score: 599
# AlwaysDefect - Wins: 4, Ties: 3, Total Score: 770
# AlwaysDefect - Wins: 4, Ties: 3, Total Score: 778
# AlwaysDefect - Wins: 4, Ties: 3, Total Score: 734
# Updated Population Size: 9
#
# --- GENERATION 5 ---
# Best Strategy of Generation 5: AlwaysDefect with score 840
# AlwaysCooperate - Wins: 0, Ties: 1, Total Score: 291
# AlwaysDefect - Wins: 4, Ties: 4, Total Score: 828
# TitForTat - Wins: 0, Ties: 2, Total Score: 622
# Mainly Nice - Wins: 1, Ties: 1, Total Score: 468
# Mainly Bad - Wins: 3, Ties: 0, Total Score: 649
# AlwaysDefect - Wins: 4, Ties: 4, Total Score: 792
# AlwaysDefect - Wins: 4, Ties: 4, Total Score: 824
# AlwaysDefect - Wins: 4, Ties: 4, Total Score: 840
# AlwaysDefect - Wins: 4, Ties: 4, Total Score: 784
# Updated Population Size: 10
#
# --- GENERATION 6 ---
# Best Strategy of Generation 6: AlwaysDefect with score 862
# AlwaysCooperate - Wins: 0, Ties: 1, Total Score: 306
# AlwaysDefect - Wins: 4, Ties: 5, Total Score: 810
# TitForTat - Wins: 0, Ties: 2, Total Score: 673
# Mainly Nice - Wins: 1, Ties: 1, Total Score: 481
# Mainly Bad - Wins: 3, Ties: 0, Total Score: 694
# AlwaysDefect - Wins: 4, Ties: 5, Total Score: 862
# AlwaysDefect - Wins: 4, Ties: 5, Total Score: 850
# AlwaysDefect - Wins: 4, Ties: 5, Total Score: 850
# AlwaysDefect - Wins: 4, Ties: 5, Total Score: 838
# AlwaysDefect - Wins: 4, Ties: 5, Total Score: 830
# Updated Population Size: 11
#
# --- GENERATION 7 ---
# Best Strategy of Generation 7: AlwaysDefect with score 940
# AlwaysCooperate - Wins: 0, Ties: 1, Total Score: 315
# AlwaysDefect - Wins: 4, Ties: 6, Total Score: 892
# TitForTat - Wins: 0, Ties: 2, Total Score: 707
# Mainly Nice - Wins: 2, Ties: 0, Total Score: 489
# Mainly Bad - Wins: 2, Ties: 1, Total Score: 697
# AlwaysDefect - Wins: 4, Ties: 6, Total Score: 884
# AlwaysDefect - Wins: 4, Ties: 6, Total Score: 908
# AlwaysDefect - Wins: 4, Ties: 6, Total Score: 908
# AlwaysDefect - Wins: 4, Ties: 6, Total Score: 916
# AlwaysDefect - Wins: 4, Ties: 6, Total Score: 940
# AlwaysDefect - Wins: 4, Ties: 6, Total Score: 920
# Updated Population Size: 12
#
# --- GENERATION 8 ---
# Best Strategy of Generation 8: AlwaysDefect with score 990
# AlwaysCooperate - Wins: 0, Ties: 1, Total Score: 306
# AlwaysDefect - Wins: 4, Ties: 7, Total Score: 958
# TitForTat - Wins: 0, Ties: 2, Total Score: 772
# Mainly Nice - Wins: 1, Ties: 1, Total Score: 507
# Mainly Bad - Wins: 3, Ties: 0, Total Score: 765
# AlwaysDefect - Wins: 4, Ties: 7, Total Score: 930
# AlwaysDefect - Wins: 4, Ties: 7, Total Score: 934
# AlwaysDefect - Wins: 4, Ties: 7, Total Score: 930
# AlwaysDefect - Wins: 4, Ties: 7, Total Score: 934
# AlwaysDefect - Wins: 4, Ties: 7, Total Score: 958
# AlwaysDefect - Wins: 4, Ties: 7, Total Score: 978
# AlwaysDefect - Wins: 4, Ties: 7, Total Score: 990
# Updated Population Size: 13
#
# --- GENERATION 9 ---
# Best Strategy of Generation 9: AlwaysDefect with score 1040
# AlwaysCooperate - Wins: 0, Ties: 1, Total Score: 279
# AlwaysDefect - Wins: 4, Ties: 8, Total Score: 1016
# TitForTat - Wins: 0, Ties: 2, Total Score: 813
# Mainly Nice - Wins: 1, Ties: 1, Total Score: 506
# Mainly Bad - Wins: 3, Ties: 0, Total Score: 791
# AlwaysDefect - Wins: 4, Ties: 8, Total Score: 1040
# AlwaysDefect - Wins: 4, Ties: 8, Total Score: 1012
# AlwaysDefect - Wins: 4, Ties: 8, Total Score: 1024
# AlwaysDefect - Wins: 4, Ties: 8, Total Score: 984
# AlwaysDefect - Wins: 4, Ties: 8, Total Score: 980
# AlwaysDefect - Wins: 4, Ties: 8, Total Score: 992
# AlwaysDefect - Wins: 4, Ties: 8, Total Score: 1008
# AlwaysDefect - Wins: 4, Ties: 8, Total Score: 1036
# Updated Population Size: 14
#
# --- GENERATION 10 ---
# Best Strategy of Generation 10: AlwaysDefect with score 1086
# AlwaysCooperate - Wins: 0, Ties: 1, Total Score: 321
# AlwaysDefect - Wins: 4, Ties: 9, Total Score: 1002
# TitForTat - Wins: 0, Ties: 3, Total Score: 870
# Mainly Nice - Wins: 1, Ties: 1, Total Score: 507
# Mainly Bad - Wins: 2, Ties: 1, Total Score: 835
# AlwaysDefect - Wins: 4, Ties: 9, Total Score: 1046
# AlwaysDefect - Wins: 4, Ties: 9, Total Score: 1054
# AlwaysDefect - Wins: 4, Ties: 9, Total Score: 1078
# AlwaysDefect - Wins: 4, Ties: 9, Total Score: 1034
# AlwaysDefect - Wins: 4, Ties: 9, Total Score: 1042
# AlwaysDefect - Wins: 4, Ties: 9, Total Score: 1066
# AlwaysDefect - Wins: 4, Ties: 9, Total Score: 1086
# AlwaysDefect - Wins: 4, Ties: 9, Total Score: 1050
# AlwaysDefect - Wins: 4, Ties: 9, Total Score: 1058
# Updated Population Size: 15
